# %%
from sympy import *
from sympy.plotting import *
init_printing(use_unicode=True)
x, y, z = symbols('x y z')

# %%
# Entre com os valores:

P = (2, -1, -3)
f = 3*y**2 - 2*x**2 + x

# Encontra a equção do plano tangente a f em P:

fx = diff(f, x).subs({x: P[0], y: P[1]})
fy = diff(f, y).subs({x: P[0], y: P[1]})

plano_tangente = P[2]+fx*(x-P[0])+fy*(y-P[1])

plano_tangente
# Out:
# -7⋅x - 6⋅y + 5

# %%
grafico = plot3d(f, (x, -4, 4), (y,-4, 4), show = False)
plano = plot3d(plano_tangente, (x, -4, 4), (y,-4, 4), show = False)

grafico.append(plano[0])

grafico.show()

# %%
plot3d(f)

# %%
f =  exp(x) * sin(y)

# Encontra a equção do plano tangente a f em P:

fx = diff(f, x)
fy = diff(f, y)

fxx = diff(fx, x)
fyy = diff(fy, y)

fxx + fyy
# Out:
# 0

# %%
f
# Out:
#  x
# ℯ ⋅sin(y)

# %%
f1 = x*exp(3*y)
f1
P = (4,0)

f1y = diff(f1, y).subs({x: P[0], y: P[1]})

# %%
f1y
# Out:
# 12
